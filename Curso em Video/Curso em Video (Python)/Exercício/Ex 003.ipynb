# %% [markdown]
# 003-Crie um program que leia dois números e mostre a soma entre eles.

# %%
n1 = int(input('Digite um número: '))
n2 = int(input('Digite outro número: '))
s = n1 + n2
print(f'A soma entre {'\033[31m'}{n1}{'\033[0m'} e {'\033[31m'}{n2}{'\033[0m'} é igual a {'\033[32m'}{s}{'\033[0m'}')
# Out:
# A soma entre 17 e 14 é igual a 31
