# %% [markdown]
# 007-Desenvolva um programa que leia as duas notas de um aluno, calcule e mostre a sua média.

# %%
n1 = float(input('Digite a primeira nota: '))
n2 = float(input('Digite a segunda nota: '))
m = (n1 + n2) / 2
print(f'A média entre {n1} e {n2} é igual a {m:.1f}')
# Out:
# A média entre 8.0 e 3.0 é igual á: 5.5

# %%
#só aumentar o codigo.
n1 = float(input('Digite a primeira nota: '))
n2 = float(input('Digite a segunda nota: '))
m = (n1 + n2) / 2
if n1 > 5.0 and n2 > 5.0 and m > 5.0:
    print(f'A média entre {'\033[36m'}{n1}{'\033[0m'} e {'\033[36m'}{n2}{'\033[0m'} é igual a {'\033[36m'}{m:.1f}{'\033[0m'}') #condição de n1 e n2 maior q 6
elif n1 > 5.0 and n2 < 5.0 and m < 6.0:
    print(f'A média entre {'\033[36m'}{n1}{'\033[0m'} e {'\033[31m'}{n2}{'\033[0m'} é igual a {'\033[31m'}{m:.1f}{'\033[0m'}') #n1 maior q 6 e n2 menor q 6
elif n1 < 5.0 and n2 > 5.0 and m < 6.0:
    print(f'A média entre {'\033[31m'}{n1}{'\033[0m'} e {'\033[36m'}{n2}{'\033[0m'} é igual a {'\033[31m'}{m:.1f}{'\033[0m'}') #n2 maior q 6 e n1 menor q 6
elif n1 < 5.0 and n2 < 5.0 and m > 5.0:
    print(f'A média entre {'\033[31m'}{n1}{'\033[0m'} e {'\033[31m'}{n2}{'\033[0m'} é igual a {'\033[36m'}{m:.1f}{'\033[0m'}')
elif n1 > 5.0 and n2 < 6.0 and m <= 5.0:
    print(f'A média entre {'\033[36m'}{n1}{'\033[0m'} e {'\033[31m'}{n2}{'\033[0m'} é igual a {'\033[31m'}{m:.1f}{'\033[0m'}')
#elif n1 < 5.0 and n2 > 5.0 and m <= 5.0: 
    #print(f'A média entre {'\033[31m'}{n1}{'\033[0m'} e {'\033[36m'}{n2}{'\033[0m'} é igual a {'\033[31m'}{m:.1f}{'\033[0m'}')
else:
    print(f'A média entre {'\033[31m'}{n1}{'\033[0m'} e {'\033[31m'}{n2}{'\033[0m'} é igual a {'\033[31m'}{m:.1f}{'\033[0m'}') #n1 e n2 menor q 6
# Out:
# A média entre 6.9 e 5.5 é igual a 6.2
