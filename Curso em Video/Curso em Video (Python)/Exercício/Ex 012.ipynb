# %% [markdown]
# 012-Faça um algoritmo que leia o preço de um produto e mostre seu novo preço, com 5% de desconto.

# %%
preco = float(input('Qual o preço do produto: R$'))
x = preco - (preco * 0.05)
#x = preco - (preco * 5 % 100) # outra forma.
print(f'{'\033[1m'}O produto no valor de R${'\033[31m'}{preco}{'\033[0m'} com {'\033[36m'}5%{'\033[0m'} de Desconto fica no valor de {'\033[32m'}{x:.1f}{'\033[0m'}R$.')~
# Out:
# O produto no valor de R$990.0 com 5% de Desconto fica no valor de 940.5R$.
