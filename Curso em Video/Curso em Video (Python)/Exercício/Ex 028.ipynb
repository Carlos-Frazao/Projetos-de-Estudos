# %% [markdown]
# 028-Escreva um programa que faça o computador "pensar" em um número inteiro entre 0 e 5 e peça para o usuário tentar descobrir qual foi o número escolhido pelo computador. O programa deverá escrever na tela se o usuário venceu ou perdeu.

# %%
from random import randint
pensar = randint(0, 5)
escolhido = int(input('Digite o número que o computador pensou? de 0 a 5 '))
if pensar == escolhido:
    print('PARABÉNS voê acerto')
else:
    print('ERROUUUU')
# Out:
# PARABÉNS voê acerto
# 4

# %%
from random import randint
from time import sleep
print('-=-' * 26)
print(f'{'\033[1;33m'}Vou pensar em um número entre 0 e 5. Tente advinhar...{'\033[0m'}')
print('-=-' * 26)
pensar = randint(0, 5)
escolhido = int(input('Em que número eu pensei? '))
print(f'{'\033[1;33m'}PROCESSANDO...{'\033[0m'}')
sleep(1)
if pensar == escolhido:
    print(f'{'\033[1;36m'}PARABÉNS!{'\033[0m'} {'\033[1;33m'}Você conseguiu me vencer pois, pensou no mesmo número que eu!{'\033[0m'}')
else:
    print(f'{'\033[1;33m'}O computador{'\033[0m'} {'\033[1;36m'}GANHOU{'\033[0m'} {'\033[1;33m'}ele pensou no{'\033[0m'} {'\033[1;32m'}{pensar}{'\033[0m'} {'\033[1;33m'}e não no{'\033[0m'} {'\033[31m'}{escolhido}!{'\033[0m'}')
# Out:
# -=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=-
# Vou pensar em um número entre 0 e 5. Tente advinhar...
# -=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=--=-
# PROCESSANDO...
# O computador GANHOU ele pensou no 1 e não no 2!
