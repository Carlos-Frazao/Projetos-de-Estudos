# %%
def main():
    nome = input('Qual é o seu nome? ')
    print(f'Olá, {nome}, prazer em te conhecer...')
if __name__ == "__main__":
    main()
# Out:
# Olá, Carlos Eduardo! prazer em te conhecer...
