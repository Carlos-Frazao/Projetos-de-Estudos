# %%
d = int(input('Dia: '))
m = str(input('Mês: '))
a = int(input('Ano: '))
idade = 2024 - a
print(f'Você nasceu no dia {d} de {m} de {a}. correto?')
print(f'Sendo assim você vai fazer {idade} neste ano...')
# Out:
# Você nasceu no dia 22 deago de 2004. correto?
# Sendo assim você vai fazer 20 neste ano...
