# %%
def main():
    algo = input('Digite algo: ')
    print(f'Logo abaixo estará todos os tipos primitivo de... {algo}')
    print(f'O tipo primitivo desse valor é?, {type(algo)}')
    print(f'Só tem espaços? ', algo.isspace())
    print(f'É um número? ', algo.isnumeric())
    print(f'É alfabético? ', algo.isalpha())
    print(f'É alfanumérico? ', algo.isalnum())
    print(f'Está em maiúscula? ', algo.isupper())
    print(f'Está em minúscula? ', algo.islower())
    print(f'Está capitalizada? ', algo.istitle())
if __name__ == "__main__":
    main()
# Out:
# Logo abaixo estará todos os tipos primitivo de...Programador
# O tipo primitivo desse valor é?, <class 'str'>
# Só tem espaços?  False
# É um número?  False
# É alfabético?  True
# É alfanumérico?  True
# Está em maiúscula?  False
# Está em minúscula?  False
# Está capitalizada?  True
