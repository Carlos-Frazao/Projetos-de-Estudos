# %%
def main():
    real = float(input("Digite um número com casa decimal: "))
    print(f"A porção inteira de {real} é {int(real)}")
    
if __name__ == "__main__":
    main()
# Out:
# A porção inteira de 6.6 é 6
