# %%
import math 
ceil = math.ceil # Função para arredondar para cima
floor = math.floor # Função para arredondar para baixo
trunc = math.trunc # Função para truncar números
pow = math.pow # Função para calcular potência
sqrt = math.sqrt # Função para calcular raiz quadrada
factorial = math.factorial # Função para calcular fatorial

# %%
import random
randint = random.randint # Função para gerar números inteiros aleatórios
uniform = random.uniform # Função para gerar números reais aleatórios
choice = random.choice # Função para escolher um elemento aleatório de uma sequência    
shuffle = random.shuffle # Função para embaralhar uma sequência
sample = random.sample # Função para obter uma amostra aleatória de uma sequência

# %%
import emoji
print(emoji.emojize("Olá, Mundo! :earth_americas:", use_aliases=True))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import emoji
#       2 print(emoji.emojize("Olá, Mundo! :earth_americas:", use_aliases=True))
#
# ModuleNotFoundError: No module named 'emoji'

# %%
import math
n = int(input('Digite um número: '))
raiz = math.sqrt(n)
print(f'A raiz de {n} é igual a {raiz:.2f}')
# Out:
# A raiz de 81 é igual a 9.00

# %%
from math import sqrt, floor
n = int(input('Digite um número: '))
raiz = sqrt(n)
print(f'A raiz de {n} é igual a {floor(raiz)}')
# Out:
# A raiz de 81 é igual a 9

# %%
import random
#n = random.random()
n = random.randint(1, 10)
print(n)
# Out:
# 9
