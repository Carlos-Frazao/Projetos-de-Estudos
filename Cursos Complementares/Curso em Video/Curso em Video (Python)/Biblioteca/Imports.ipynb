# %%
import math
#Importa a Biblioteca de matemática.

from math import trunc
#Ele vai truncar o número e restornará sua parte inteira.

from math import sqrt
#Raiz quadrada.

from math import pow
#Potência.

from math import hypot
#Hipotenusa.

import random
#Números váriantes.

import pygame
#Importa Biblioteca de games.

from time import sleep
#Importa a Biblioteca de tempo.

from datetime import date
váriavel = date.today().year
#Essa Biblioteca pega a data atual do pc.

import webbrowser
webbrowser.open('')
#Essa Biblioteca abri uma aba no navegador.
