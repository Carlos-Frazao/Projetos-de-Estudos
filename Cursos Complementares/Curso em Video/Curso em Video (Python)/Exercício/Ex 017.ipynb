# %% [markdown]
# 017-Faça um programa que leia o comprimento do cateto oposto e do cateto adjacente de um triângulo retângulo. Calcule e mostre o comprimento da hipotenusa.

# %%
opost = float(input('Comprimento do Cateto Oposto: '))
adjac = float(input('Comprimento do Cateto Adjacente: '))
hi = (opost ** 2 + adjac ** 2) ** (1/2)
print(f'A Hipotenusa vai medir {hi:.2f}')
# Out:
# A Hipotenusa vai medir 5.00

# %%
from math import sqrt, pow
opost = float(input('Comprimento do Cateto Oposto: '))
adjac = float(input('Comprimento do Cateto Adjacente: '))
x = (opost ** 2) + (adjac ** 2)
#x1 = sqrt(x)
print(f'A Hipotenusa vai medir {sqrt(x):.2f}.')
# Out:
# A Hipotenusa vai medir 5.00.

# %%
import math
opost = float(input('Comprimento do Cateto Oposto: '))
adjacent = float(input('Comprimento do Cateto Adjacente: '))
hi = math.hypot(opost, adjac)
print(f'A Hipotenusa vai medir {hi:.2f}')
# Out:
# A Hipotenusa vai medir 3.20

# %%
from math import hypot
opost = float(input('Comprimento do Cateto Oposto: '))
adjac = float(input('Comprimento do Cateto Adjacente: '))
hi = hypot(opost, adjac)
print(f'A Hipotenusa vai medir {'\033[36m'}{hi:.2f}{'\033[0m'}')
# Out:
# A Hipotenusa vai medir 5.00
