# %% [markdown]
# 024-Crie um programa que leia o nome de uma cidade diga se ela começa ou não com o nome "SANTO".

# %%
cid = str(input('Digite o nome de uma Cidade? ')).strip()
print(cid[:5].upper() == 'SANTO')
# Out:
# False

# %%
cidade = str(input('Digite o nome de uma Cidade? ')).strip()
cidade = cidade.split()
divisao = cidade[0]
x = divisao.upper() == 'SANTO'
if divisao.upper() == 'SANTO':
    print(f'{'\033[1;33m'}A cidade informada possui{'\033[0m'} {'\033[1;31m'}(Santo){'\033[0m'} {'\033[1;33m'}no nome:{'\033[0m'} {'\033[1;36m'}{x}{'\033[0m'}')
else:
    print(f'{'\033[1;33m'}A cidade informada possui{'\033[0m'} {'\033[1;31m'}(Santo){'\033[0m'} {'\033[1;33m'}no nome:{'\033[0m'} {'\033[1;31m'}{x}{'\033[0m'}')
# Out:
# A cidade informada possui (Santo) no nome: False
