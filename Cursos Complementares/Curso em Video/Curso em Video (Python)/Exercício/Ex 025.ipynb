# %% [markdown]
# 025-Crie um programa que leia o nome de uma pessoa e diga se ela tem "SILVA" no nome.

# %%
nome = str(input('Informe seu nome completo? ')).strip()
print(f'Seu nome tem Silva? {'silva' in nome.lower()}')
# Out:
# Seu nome tem Silva? True

# %%
nome = str(input('Informe seu nome completo? ')).strip().lower()
nome_d = nome.split()
x = nome_d[:]
x = 'silva' in nome_d
if 'silva' in nome_d:
    print(f'{'\033[1;33m'}Seu nome completo é,{'\033[0m'} {'\033[1;36m'}{nome}{'\033[0m'} {'\033[1;33m'}e possui silva?{'\033[0m'} {'\033[32m'}{x}{'\033[0m'}.')
else:
    print(f'{'\033[1;33m'}Seu nome completo é,{'\033[0m'} {'\033[1;36m'}{nome},{'\033[0m'} {'\033[1;33m'}e possui silva?{'\033[0m'} {'\033[31m'}{x}{'\033[0m'}.')
# Out:
# Seu nome completo é, carlos silvas, e possui silva? False.
