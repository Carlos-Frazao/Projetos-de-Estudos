# %% [markdown]
# 033-Faça um programa que leia três números e mostre qual é o maior e qual é o menor.

# %%
num1 = int(input('Digite um número qualquer: '))
num2 = int(input('Digite outro número qualquer: '))
num3 = int(input('Digite o último número qualquer: '))
#Verificando menor valor a - b e a - c
menor = num1
if num2 < num3 and num2 < num1:
    menor = num2
if num3 < num2 and num3 < num1:
    menor = num3
print(f'{'\033[1;33m'}O{'\033[0m'} {'\033[1;31m'}menor{'\033[0m'} {'\033[1;33m'}valor digitado foi{'\033[0m'} {'\033[1;31m'}{menor}.{'\033[0m'} ')
#Verificando o maior valor
maior = num1
if num2 > num3 and num2 > num1:
    maior = num2
if num3 > num2 and num3 >  num1:
    maior = num3
print(f'{'\033[1;33m'}O{'\033[0m'} {'\033[1;36m'}maior{'\033[0m'} {'\033[1;33m'}valor digitadoo foi {'\033[1;36m'}{maior}.{'\033[0m'}')
# Out:
# O menor valor digitado foi 6
# O maior valor digitadoo foi 18
