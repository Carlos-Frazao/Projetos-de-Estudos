# %% [markdown]
# Style:                                          Text:                    Back:
# 0 == Nome (sem estilo)                          30 == Branco             40 == Branco
# 1 == Bold (negrito)                             31 == Vermelho           41 == Vermmelho
# 4 == Underline (sublinhado)                     32 == Verde              42 == Verde
# 7 == Negative (inverter, fundo e letra)         33 == Amarelo            43 == Amarelo
#                                                 34 == Azul               44 == Azul
#                                                 35 == Magento            45 == Magento
#                                                 36 == Ciano              46 == Ciano
#                                                 37 == Cinza              47 == Cinza
# ESTRUTURA: \033[0;33;44m

# %%
\033[0;30;41m
