# %%
print('\033[7;33;44mOlá, Mundo!')
# Out:
# Olá, Mundo!

# %%
a = 3
b = 5
print(f'Os valores são \033[32m{a}\33[m e \033[31m{b}\033[m')
# Out:
# Os valores são 3 e 5

# %%
nome = 'Carlos'
print(f'Olá! Muito prazer em te conhecer, {'\033[4;34m'}{nome}{'\033[0m'}!!!')
# Out:
# Olá! Muito prazer em te conhecer, Carlos!!!

# %%
nome = 'Carlos'
cores = {'limpa':'\033[0m',
         'azul':'\033[34m',
         'amarelo':'\033[33m',
         'pretoebranco':'\033[7;30m'}
print(f'Olá! Muito prazer em te conhecer, {cores['azul']}{nome}{cores["limpa"]}!!!')
# Out:
# Olá! Muito prazer em te conhecer, Carlos!!!
