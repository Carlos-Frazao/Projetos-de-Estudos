# %%
for c in range(0, 5):
    print(c)
print('FIM')
# Out:
# 0
# 1
# 2
# 3
# 4
# FIM

# %%
for c in range(0, 5):
    print('Oi')
    print('FIM')
# Out:
# Oi
# FIM
# Oi
# FIM
# Oi
# FIM
# Oi
# FIM
# Oi
# FIM

# %%
n = int(input('Digite um número: '))
for c in range(1, n + 1):
    print(c)
print('FIM')
# Out:
# 1
# 2
# 3
# 4
# 5
# FIM
