# %%
def main():
    valor = int(input("Informe um valor: "))
    print(f"Analisando o valor {valor}, seu sucessor é {valor + 1} e seu antecessor é {valor - 1}")
if __name__ == "__main__":
    main()
# Out:
# Analisando o valor 5, seu sucessor é 6 e seu antecessor é 4
