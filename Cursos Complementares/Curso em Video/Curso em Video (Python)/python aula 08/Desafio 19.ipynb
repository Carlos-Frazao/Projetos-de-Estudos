# %%
from random import choice

def main():
    try:
        sequencia = ["Primeiro aluno: ", "Segundo aluno: ", "Terceiro aluno: ", "Quarto aluno: "]
        alunos = []

        for i in range(1, qtd + 1):
            alunos.append(input(f"Nome do {sequencia[i-1]}: "))

        # Sorteio do aluno
        if alunos:
            escolhido = choice(alunos)
            print(f"Sorteio realizado!")
            print(f"O aluno que vai começar é: {escolhido}")

    except ValueError:
        print("Erro: Por favor, digite um número inteiro para a quantidade de 4 alunos.")

if __name__ == "__main__":
    main()
# Out:
# Sorteio realizado!
# O aluno que vai começar é: gvvvg
